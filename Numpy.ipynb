# %%
import numpy as np

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[8,3,2,5],[12,23,34,54]])
print(b)
b.shape
# Out:
# [[ 8  3  2  5]
#  [12 23 34 54]]
# (2, 4)

# %%
b[1,0]
# Out:
# np.int64(12)

# %%
b[1,2]=100
print(b)
# Out:
# [[  8   3   2   5]
#  [ 12  23 100  54]]

# %%
b[:,2]=5
print(b)
# Out:
# [[ 8  3  5  5]
#  [12 23  5 54]]

# %%
c = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(c)

c[0,1,1]
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
# np.int64(4)

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.ones((4, 2))
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
np.full((2,2),(99))
# Out:
# array([[99, 99],
#        [99, 99]])

# %%
np.random.rand(4,5)
# Out:
# array([[0.42857062, 0.35531433, 0.2896802 , 0.82902412, 0.40111776],
#        [0.83119917, 0.57411842, 0.41756329, 0.69053733, 0.09924545],
#        [0.98793744, 0.04707444, 0.31939493, 0.88568845, 0.40066985],
#        [0.53328436, 0.73127755, 0.53875292, 0.61855879, 0.76544271]])

# %%
f=np.array([4,5,6,7])
g=f.copy()
print(g)
# Out:
# [4 5 6 7]

# %%
g + 2
# Out:
# array([6, 7, 8, 9])

# %%
f + b
# Out:
# array([[12,  8, 11, 12],
#        [16, 28, 11, 61]])

# %%
np.cos(a)
# Out:
# array([ 0.54030231, -0.41614684, -0.9899925 ])

# %%
j=np.ones((2,3))
print(j)
k=np.full((3,2),4)
print (k)
np.matmul(j, k)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]
# [[4 4]
#  [4 4]
#  [4 4]]
# array([[12., 12.],
#        [12., 12.]])
